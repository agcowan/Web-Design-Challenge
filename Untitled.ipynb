# %%
import pandas as pd

# %%
path = "resources/cities.csv"
cities_df = pd.read_csv(path)
cities_df.head()
# Out:
#              City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0           Minna   9.6139    6.5569     79.65        66         100
# 1            Jalu  29.0331   21.5482     73.49        20         100
# 2         Rikitea -23.1203 -134.9692     75.94        74          96
# 3          Acaraú  -2.8856  -40.1200     77.74        86          49
# 4  Port Elizabeth -33.9180   25.5701     57.31        82           0
#
#    Wind Speed Country        Date
# 0        5.39      NG  1650939128
# 1        9.44      LY  1650939039
# 2       19.35      PF  1650939129
# 3       10.42      BR  1650939129
# 4        7.00      ZA  1650939130

# %%
table = cities_df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lon</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Minna</td>
#       <td>9.6139</td>
#       <td>6.5569</td>
#       <td>79.65</td>
#       <td>66</td>
#       <td>100</td>
#       <td>5.39</td>
#       <td>NG</td>
#       <td>1650939128</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jalu</td>
#       <td>29.0331</td>
#       <td>21.5482</td>
#       <td>73.49</td>
#       <td>20</td>
#       <td>100</td>
#       <td>9.44</td>
#       <td>LY</td>
#       <td>1650939039</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>75.94</td>
# ...
